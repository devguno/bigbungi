# %%
import pandas as pd

# %% [markdown]
# ## Question 64

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/timeTest.csv')
df.head()
# Out:
#      Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Yr_Mo_Dy  6574 non-null   object
#  1   RPT       6568 non-null   float64
#  2   VAL       6571 non-null   float64
#  3   ROS       6572 non-null   float64
#  4   KIL       6569 non-null   float64
#  5   SHA       6572 non-null   float64
#  6   BIR       6574 non-null   float64
#  7   DUB       6571 non-null   float64
#  8   CLA       6572 non-null   float64
#  9   MUL       6571 non-null   float64
#  10  CLO       6573 non-null   float64
#  11  BEL       6574 non-null   float64
#  12  MAL       6570 non-null   float64
# dtypes: float64(12), object(1)
# memory usage: 667.8+ KB

# %%
df['Yr_Mo_Dy'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6574 entries, 0 to 6573
# Series name: Yr_Mo_Dy
# Non-Null Count  Dtype
# --------------  -----
# 6574 non-null   object
# dtypes: object(1)
# memory usage: 51.5+ KB

# %%
df['Yr_Mo_Dy']= pd.to_datetime(df['Yr_Mo_Dy'])

# %%
df['Yr_Mo_Dy']
# Out:
# 0      2061-01-01
# 1      2061-01-02
# 2      2061-01-03
# 3      2061-01-04
# 4      2061-01-05
#           ...
# 6569   1978-12-27
# 6570   1978-12-28
# 6571   1978-12-29
# 6572   1978-12-30
# 6573   1978-12-31
# Name: Yr_Mo_Dy, Length: 6574, dtype: datetime64[ns]

# %%
sorted(df['Yr_Mo_Dy'].dt.year.unique(),reverse=True)
# Out:
# [2070,
#  2069,
#  2068,
#  2067,
#  2066,
#  2065,
#  2064,
#  2063,
#  2062,
#  2061,
#  1978,
#  1977,
#  1976,
#  1975,
#  1974,
#  1973,
#  1972,
#  1971]

# %%
df['Yr_Mo_Dy'] = pd.to_datetime(df['Yr_Mo_Dy'].astype('str').\
    map(lambda x: str(int(x[:4])-100)+x[4:] if x[:4] >= '2061' else x))

# %%
df.Yr_Mo_Dy.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6574 entries, 0 to 6573
# Series name: Yr_Mo_Dy
# Non-Null Count  Dtype
# --------------  -----
# 6574 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 51.5 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Yr_Mo_Dy  6574 non-null   datetime64[ns]
#  1   RPT       6568 non-null   float64
#  2   VAL       6571 non-null   float64
#  3   ROS       6572 non-null   float64
#  4   KIL       6569 non-null   float64
#  5   SHA       6572 non-null   float64
#  6   BIR       6574 non-null   float64
#  7   DUB       6571 non-null   float64
#  8   CLA       6572 non-null   float64
#  9   MUL       6571 non-null   float64
#  10  CLO       6573 non-null   float64
#  11  BEL       6574 non-null   float64
#  12  MAL       6570 non-null   float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 667.8 KB

# %%
# 날짜 형식 변환
df['Yr_Mo_Dy'] = pd.to_datetime(df['Yr_Mo_Dy'])

df['year']=df['Yr_Mo_Dy'].dt.year
df.groupby(df['year']).mean()
# Out:
#                 Yr_Mo_Dy        RPT        VAL        ROS       KIL  \
# year
# 1961 1961-07-02 00:00:00  12.299583  10.351796  11.362369  6.958227
# 1962 1962-07-02 00:00:00  12.246923  10.110438  11.732712  6.960440
# 1963 1963-07-02 00:00:00  12.813452  10.836986  12.541151  7.330055
# 1964 1964-07-01 12:00:00  12.363661  10.920164  12.104372  6.787787
# 1965 1965-07-02 00:00:00  12.451370  11.075534  11.848767  6.858466
# 1966 1966-07-02 00:00:00  13.461973  11.557205  12.020630  7.345726
# 1967 1967-07-02 00:00:00  12.737151  10.990986  11.739397  7.143425
# 1968 1968-07-01 12:00:00  11.835628  10.468197  11.409754  6.477678
# 1969 1969-07-02 00:00:00  11.166356   9.723699  10.902000  5.767973
# 1970 1970-07-02 00:00:00  12.600329  10.726932  11.730247  6.217178
# 1971 1971-07-02 00:00:00  11.273123   9.095178  11.088329  5.241507
# 1972 1972-07-01 12:00:00  12.463962  10.561311  12.058333  5.929699
# 1973 1973-07-02 00:00:00  11.828466  10.680493  10.680493  5.547863
# ...

# %%
df['weekday'] = df['Yr_Mo_Dy'].dt.day_of_week
df
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL  year  weekday
# 0     10.83  12.58  18.50  15.04  1961        6
# ...

# %%
df['WeekCheck'] = df['weekday'].map(lambda x : 1 if x in [5,6] else 0)
df['WeekCheck'].value_counts()
# Out:
# WeekCheck
# 0    4695
# 1    1879
# Name: count, dtype: int64

# %%
ans = df.groupby(df['Yr_Mo_Dy'].dt.month).mean()
ans = ans.drop(columns='Yr_Mo_Dy')
ans.index.name = 'Month'
ans
# Out:
#              RPT        VAL        ROS       KIL        SHA       BIR  \
# Month
# 1      14.847325  12.914560  13.299624  7.199498  11.667734  8.054839
# 2      13.710906  12.111122  12.879132  6.942411  11.551772  7.633858
# 3      13.158687  11.505842  12.648118  7.265907  11.554516  7.959409
# 4      12.555648  10.429759  12.204815  6.898037  10.677667  7.441389
# 5      11.724032  10.145619  11.550394  6.307487  10.224301  6.942061
# 6      10.451317   8.949704  10.361315  5.652278   9.529926  6.410093
# 7       9.992007   8.357778   9.349642  5.416935   9.302634  5.972348
# 8      10.213411   8.415143   9.993441  5.270681   8.901559  5.891057
# 9      11.458519   9.981002  10.756883  5.615176   9.766315  6.566222
# 10     12.660610  11.010681  11.453943  6.065215  10.550251  7.159910
# 11     13.200722  11.639500  12.293407  6.247611  10.501130  7.134333
# 12     14.446398  12.353602  13.212276  6.829910  11.301254  7.963710
#
# ...

# %%
df.isnull().sum()
# Out:
# Yr_Mo_Dy     0
# RPT          6
# VAL          3
# ROS          2
# KIL          5
# SHA          2
# BIR          0
# DUB          3
# CLA          2
# MUL          3
# CLO          1
# BEL          0
# MAL          4
# year         0
# weekday      0
# WeekCheck    0
# dtype: int64

# %%
df[df.RPT.isnull()]
# Out:
#       Yr_Mo_Dy  RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# 28  1961-01-29  NaN  23.91  22.29  17.54  24.08  19.70  22.00  20.25  21.46
# 70  1961-03-12  NaN  13.88  16.38  10.25  14.92  13.67  17.12  13.70  16.29
# 179 1961-06-29  NaN  10.46   7.96   6.79  12.62   7.08   8.33   9.46   7.08
# 222 1961-08-11  NaN   6.75   8.29   5.00   8.58   4.83   6.83   6.25   5.79
# 284 1961-10-12  NaN   8.71   4.67   3.67   9.08   6.54   5.58   6.38   4.00
# 427 1962-03-04  NaN   5.33  13.50   6.13   6.46   2.71   5.33   3.79   4.46
#
#        CLO    BEL    MAL  year  weekday  WeekCheck
# 28   19.95  27.71  23.38  1961        6          1
# 70   15.79  20.50  22.54  1961        6          1
# 179  10.92  20.88  10.79  1961        3          0
# 222   5.25   5.88   8.38  1961        4          0
# 284   5.37  12.46  10.75  1961        3          0
# 427   4.04   2.71   7.08  1962        6          1

# %%
df.iloc[[27,28,29],:].fillna
# Out:
#      Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# 27 1961-01-28  17.67  13.54  13.33   8.87  15.04  11.63  12.25  10.58  11.92
# 28 1961-01-29    NaN  23.91  22.29  17.54  24.08  19.70  22.00  20.25  21.46
# 29 1961-01-30  12.21  11.42  10.92   7.92  13.08   9.62  14.50  10.21   9.92
#
#       CLO    BEL    MAL  year  weekday  WeekCheck
# 27  11.04  20.30  18.12  1961        5          1
# 28  19.95  27.71  23.38  1961        6          1
# 29  11.96  18.88  19.25  1961        0          0

# %%
df.iloc[[27,28,29],:].fillna(method='ffill')
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_17744\847673428.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.iloc[[27,28,29],:].fillna(method='ffill')
#      Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# 27 1961-01-28  17.67  13.54  13.33   8.87  15.04  11.63  12.25  10.58  11.92
# 28 1961-01-29  17.67  23.91  22.29  17.54  24.08  19.70  22.00  20.25  21.46
# 29 1961-01-30  12.21  11.42  10.92   7.92  13.08   9.62  14.50  10.21   9.92
#
#       CLO    BEL    MAL  year  weekday  WeekCheck
# 27  11.04  20.30  18.12  1961        5          1
# 28  19.95  27.71  23.38  1961        6          1
# 29  11.96  18.88  19.25  1961        0          0

# %%
df=df.fillna(method='ffill').fillna(method='bfill')
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_17744\1638694757.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df=df.fillna(method='ffill').fillna(method='bfill')

# %%
df.isnull().sum()
# Out:
# Yr_Mo_Dy     0
# RPT          0
# VAL          0
# ROS          0
# KIL          0
# SHA          0
# BIR          0
# DUB          0
# CLA          0
# MUL          0
# CLO          0
# BEL          0
# MAL          0
# year         0
# weekday      0
# WeekCheck    0
# dtype: int64

# %%
df.drop(columns='Yr_Mo_Dy').groupby(df['Yr_Mo_Dy'].dt.strftime('%Y-%m')).mean()
# Out:
#                 RPT        VAL        ROS       KIL        SHA        BIR  \
# Yr_Mo_Dy
# 1961-01   14.932581  12.084194  13.431613  7.736774  11.215806   8.588065
# 1961-02   16.269286  14.975357  14.324643  9.116786  13.852143  10.937500
# 1961-03   11.015806  11.296452  10.752903  7.137742  10.509355   8.866774
# 1961-04   10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05    9.860968   8.735161  10.818065  5.892258   9.490323   6.574839
# ...             ...        ...        ...       ...        ...        ...
# 1978-08    9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09   10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10    9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11   16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12   16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %%
df.loc[:,'diff'] = df['RPT'].diff()

# %%
df
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    1961-01-01  15.04  14.96  13.17   9.29  12.62   9.87  13.67  10.25
# 1    1961-01-02  14.71  14.96  10.83   6.50  12.62   7.67  11.50  10.04
# 2    1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25  10.04
# 3    1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL  year  weekday  WeekCheck  diff
# ...

# %%
df[['RPT_rol','VAL_rol']]= df[['RPT','VAL']].rolling(7).mean()

# %%
df
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    1961-01-01  15.04  14.96  13.17   9.29  12.62   9.87  13.67  10.25
# 1    1961-01-02  14.71  14.96  10.83   6.50  12.62   7.67  11.50  10.04
# 2    1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25  10.04
# 3    1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL  year  weekday  WeekCheck  diff    RPT_rol  \
# ...

# %% [markdown]
# ## 76~~~~
